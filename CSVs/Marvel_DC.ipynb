# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df1 = pd.read_csv('marvel_characters_info.csv')
df2 = pd.read_csv('charcters_stats.csv')

df1['Name']
# Out:
# 0               A-Bomb
# 1           Abe Sapien
# 2             Abin Sur
# 3          Abomination
# 4              Abraxas
#             ...
# 729    Yellowjacket II
# 730               Ymir
# 731               Yoda
# 732            Zatanna
# 733               Zoom
# Name: Name, Length: 734, dtype: object

# %%
df2['Name']
# Out:
# 0              3-D Man
# 1               A-Bomb
# 2           Abe Sapien
# 3             Abin Sur
# 4          Abomination
#             ...
# 606       Yellowjacket
# 607    Yellowjacket II
# 608               Ymir
# 609            Zatanna
# 610               Zoom
# Name: Name, Length: 611, dtype: object

# %%
marvel = pd.DataFrame(columns=df2.head(0))
dc = pd.DataFrame(columns=df2.head(0))
marvel_list = []
dc_list = []
for name in df2['Name']:
    if name in list(df1['Name']):
        marvel_list.append(name)
    else:
        dc_list.append(name)
marvel_list = pd.Series(marvel_list)   
dc_list = pd.Series(dc_list)

# %%
marvel_list
# Out:
# 0               A-Bomb
# 1           Abe Sapien
# 2             Abin Sur
# 3          Abomination
# 4              Abraxas
#             ...
# 577       Yellowjacket
# 578    Yellowjacket II
# 579               Ymir
# 580            Zatanna
# 581               Zoom
# Length: 582, dtype: object

# %%
dc_list
# Out:
# 0              3-D Man
# 1            Agent  13
# 2               Atom I
# 3            Batgirl I
# 4           Batgirl II
# 5       Black Canary I
# 6      Black Canary II
# 7           Blizzard I
# 8        Blue Beetle I
# 9            Boom Boom
# 10           Cheetah I
# 11    Crimson Dynamo I
# 12             Flash I
# 13          Goliath II
# 14         Goliath III
# 15         Hawkwoman I
# 16             Ironman
# 17           Jack-jack
# 18           Ms Marvel
# 19          Mysterio I
# 20         Oracle (DC)
# 21             Robin I
# 22      Silk Spectre I
# 23           Spiderman
# 24         Sub-Mariner
# 25          Super Moos
# 26       Vindicator II
# 27              Violet
# 28      Willis Stryker
# dtype: object

# %%
marvel_df = df2.loc[df2['Name'].isin(marvel_list)]

# %%
dc_df = df2.loc[df2['Name'].isin(dc_list)]

# %%
dc_df
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0             3-D Man      good            50        31     43          32
# 8           Agent  13      good             1         1      1           1
# 44             Atom I      good             1         1      1           1
# 55          Batgirl I      good             1         1      1           1
# 56         Batgirl II      good             1         1      1           1
# 86     Black Canary I      good             1         1      1           1
# 87    Black Canary II      good             1         1      1           1
# 104        Blizzard I       bad             1         1      1           1
# 111     Blue Beetle I      good             1         1      1           1
# 116         Boom Boom      good            38        10     12          42
# 152         Cheetah I       bad             1         1      1           1
# ...

# %%
dc_df.sort_values(by='Strength',ascending=False)
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 531       Sub-Mariner      good            63        80     47          56
# 400         Ms Marvel      good            63        80     47          52
# 575     Vindicator II      good            63        63     53          64
# 305         Jack-jack      good             6        34     67          80
# 0             3-D Man      good            50        31     43          32
# 593    Willis Stryker       bad            38        16     23          28
# 467           Robin I      good            88        11     27          28
# 423       Oracle (DC)      good            75        11     23          28
# 403        Mysterio I       bad            75        10     23          42
# 116         Boom Boom      good            38        10     12          42
# 229           Flash I      good            63        10    100          50
# ...

# %%
 marvel_df.sort_values(by='Strength',ascending=False)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 1               A-Bomb      good            38       100     17          80
# 361  Martian Manhunter      good           100       100     96         100
# 180           Darkseid       bad            88       100     23         100
# 238           Galactus   neutral           100       100     83         100
# 318         Juggernaut   neutral            44       100     42         100
# ..                 ...       ...           ...       ...    ...         ...
# 462       Renata Soliz      good             1         1      1           1
# 200         Donna Troy      good             1         1      1           1
# 466            Ripcord      good             1         1      1           1
# 468           Robin II      good             1         1      1           1
# 309             Jigsaw       bad             1         1      1           1
#
#      Power  Combat  Total
# 1       17      64    316
# ...

# %%
sns.set_theme()
ax1 = sns.boxplot(x=  df2['Strength'])
plt.savefig('marvel_dc_str.pdf')
plt.clf()

# %%
ax2 = sns.boxplot(x=  marvel_df['Strength'])
plt.savefig('marvel_str.pdf')
plt.clf()

# %%
ax3 = sns.boxplot(x=  dc_df['Strength'])
plt.savefig('dc_str.pdf')
